# %% [markdown]
# **Print()** **Statements**

# %% [markdown]
# Basic Syntax of print()

# %% [markdown]
# print(*objects, sep=' ', end='\n', file=sys.stdout, fliush=False)

# %% [markdown]
# Printing a string

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Printing Numbers

# %%
print(42)
print(3.14)
# Out:
# 42
# 3.14

# %% [markdown]
# Printing multiple objects

# %%
x=10
y=20
print("the value of x is ", x, "and the value of y is ", y)
# Out:
# the value of x is  10 and the value of y is  20

# %% [markdown]
# Customising the separator

# %%
print("apple","banana","cherry", sep=",")
# Out:
# apple,banana,cherry

# %% [markdown]
# No Separator

# %%
print("apple","banana","cherry",sep="")
# Out:
# applebananacherry

# %% [markdown]
# Custom End Character

# %%
print("Hello", end=" ")
print("World!")
# Out:
# Hello World!

# %% [markdown]
# No LIne Break

# %%
print("Hello", end="")
print("World!")
# Out:
# HelloWorld!
