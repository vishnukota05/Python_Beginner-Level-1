# %%
10+5
# Out:
# 15

# %%
10-5
# Out:
# 5

# %%
2*3
# Out:
# 6

# %%
2**3
# Out:
# 8

# %%
3**2
# Out:
# 9

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
# BODMAS (BRACKET, ORDER, DIVISION, MULTIPLICATION, ADDTION, SUBTRACTION)
(10+5)*2
# Out:
# 30

# %%
10+5*2
# Out:
# 20

# %%
_+3
# Out:
# 23

# %%
_+3
# Out:
# 26
