# %% [markdown]
# USER INPUT FINCTIONS IN PYTHON

# %%
x= input()
y= input()
z= x +y
print(z)
# Out:
# 5
# 6
# 56

# %%
x1=input('enter the 1st number')
y1=input('enter the 2nd number')
z1=x1+y1
print(z1)
# Out:
# enter the 1st number8
# enter the 2nd number6
# 86

# %%
type(x1)
type(y1)
# Out:
# str

# %%
x1=input ('enter the 1st number')
a1=int(x1)
y1=input ('enter the 2nd number')
b1=int(y1)
z1=a1 + b1
print(z1)
# Out:
# enter the 1st number5
# enter the 2nd number4
# 9

# %% [markdown]
# for the above code notice we are using many lines because of that wasting some memory spaces as well.

# %%
x2= int (input('enter the 1st number'))
y2= int (input('enter the 2nd number'))
z2= x2 + y2
print(z2)
# Out:
# enter the 1st number89
# enter the 2nd number21
# 110

# %% [markdown]
# let's take input from the user in char format,but we don't have char format in python.

# %%
ch = input('enter a character')
print(ch)
# Out:
# enter a charactervishnu
# vishnu

# %%
print(ch[0])
# Out:
# v

# %%
print(ch[1])
# Out:
# i

# %%
print(ch[-1])
# Out:
# u

# %%
ch = input('enter a character')[0]
print(ch)
# Out:
# enter a characterkusuma
# k

# %%
ch = input('enter a character')[1:3]
print(ch)
# Out:
# enter a characterkusuma
# us

# %%
ch = input('enter a character')
print(ch)
# Out:
# enter a character2+6-1
# 2+6-1

# %% [markdown]
# EVAL function using input

# %%
result = eval(input('enter an expression'))
print(result)
# Out:
# enter an expression2+3-8*9/5
# -9.4

# %% [markdown]
# **import** **math** **module**

# %% [markdown]
# https://docs.python.org/3/library/math.html

# %%
x=sqrt(25)

# %%
import math

# %%
x=math.sqrt(25)
x
# Out:
# 5.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
print(math.floor(2.9)) #floor - minimum or least value
# Out:
# 2

# %%
print(math.ceil(2.3)) #ceil - maximum or least value
# Out:
# 3

# %%
print(math.pow(3,2))
# Out:
# 9.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
import math as m
m.sqrt(10)
# Out:
# 3.1622776601683795

# %%
from math import sqrt,pow
pow(3,2)
# Out:
# 9.0

# %%
round(pow(2,3))
# Out:
# 8
