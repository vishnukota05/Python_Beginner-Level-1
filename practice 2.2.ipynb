# %% [markdown]
# **RULES TO DEFINE PYTHON VARIABLES**

# %%
v = 23
v
# Out:
# 23

# %%
1v = 34
1v
# Out:
#   File "<ipython-input-3-eba42c704729>", line 1
#     1v = 34
#     ^
# SyntaxError: invalid decimal literal

# %%
v1 = 50
v1
# Out:
# 50

# %%
def = 78
def
# Out:
#   File "<ipython-input-5-fd701a733b6b>", line 1
#     def = 78
#         ^
# SyntaxError: invalid syntax

# %%
Def = 78
Def
# Out:
# 78

# %%
NIT = 25
nit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1a2eb912748c> in <cell line: 0>()
#       1 NIT = 25
# ----> 2 nit
#
# NameError: name 'nit' is not defined

# %%
NIT
# Out:
# 25

# %%
h_=80

# %%
t=89

# %%
t
# Out:
# 89

# %%
aaaaaaaaaaaa = 90
aaaaaaaaaaaa
# Out:
# 90

# %%
# variable concept we are cleared

# %%
a = 10
a
# Out:
# 10

# %%
a =20
a
# Out:
# 20

# %%
a,b,c =10,20,30
a
b
c
# Out:
# 30

# %%
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
print(a,b,c)
# Out:
# 10 20 30

# %%
1nit = 67
# Out:
#   File "<ipython-input-22-9ecadba99187>", line 1
#     1nit = 67
#     ^
# SyntaxError: invalid decimal literal

# %%
_nit = 78
_nit
# Out:
# 78

# %%
a b =7
# Out:
#   File "<ipython-input-24-49ba196d3eb6>", line 1
#     a b =7
#       ^
# SyntaxError: invalid syntax

# %%
if = 90
# Out:
#   File "<ipython-input-25-1a3b7d5116d5>", line 1
#     if = 90
#        ^
# SyntaxError: invalid syntax

# %%
IF = 89
IF
# Out:
# 89

# %% [markdown]
# **HOW TO DEFINE VARIABLE WE ARE COMPLETED**

# %% [markdown]
# DATA TYPE (PRIMITIVE)
#
# *   INT = number without decimal
# *   FLOAT = number with decimal (petrol price, salary)
# *   COMPLEX = REAL PART + IMAGINARY PART (only j letter is allowed)
# *   BOOL = TRUE OR FALSE
# *   STRING

# %% [markdown]
# Variable_Nmae = value

# %% [markdown]
# **int**

# %%
i = 4
i
# Out:
# 4

# %%
print(type(i))
# Out:
# <class 'int'>

# %% [markdown]
# float

# %%
f = 110.78
print(f)
print(type(f))
# Out:
# 110.78
# <class 'float'>

# %%
f1 = 3e0
f1
# Out:
# 3.0

# %%
f2 = 3e1
f2
# Out:
# 30.0

# %%
f3 = 3e2
f3
# Out:
# 300.0

# %%
f4 = 2.3e3
f4
# Out:
# 2300.0

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-92d7f0de9a24> in <cell line: 0>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-b73d74fcede9> in <cell line: 0>()
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
False
# Out:
# False

# %%
FALSE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-d5612866378f> in <cell line: 0>()
# ----> 1 FALSE
#
# NameError: name 'FALSE' is not defined

# %%
none
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-02135ff9133d> in <cell line: 0>()
# ----> 1 none
#
# NameError: name 'none' is not defined

# %%
None

# %%
True + False
# Out:
# 1

# %%
True
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
True + False * True - False
# Out:
# 1

# %%
True + (False * True) - False
# Out:
# 1

# %%
True + (False * True) - True
# Out:
# 0

# %%
b =True + (False * True) - True
b
# Out:
# 0

# %%
num1=20
num2=30
add=num1+num2
add
# Out:
# 50

# %%
num1=20
num2=30
add=num1+num2
print('The addition of', num1, 'and', num2, 'is=', add)
# Out:
# The addition of 20 and 30 is= 50

# %% [markdown]
# COMPLEX

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
d = 30 + 40j

# %%
print(c)
print(d)
# Out:
# (10+20j)
# (30+40j)

# %%
c + d
# Out:
# (40+60j)

# %%
a = '5.5'
type(a)
# Out:
# str

# %%
c - d
# Out:
# (-20-20j)

# %%
a
# Out:
# '5.5'

# %%
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imaginary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-5a7caf8e287d> in <cell line: 0>()
# ----> 1 c.imaginary
#
# AttributeError: 'complex' object has no attribute 'imaginary'

# %%
c.imag
# Out:
# 20.0
